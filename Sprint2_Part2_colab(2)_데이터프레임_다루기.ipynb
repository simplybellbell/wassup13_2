# %% [markdown]
# <a href="https://colab.research.google.com/github/simplybellbell/wassup13_2/blob/main/Sprint2_Part2_colab(2)_%EB%8D%B0%EC%9D%B4%ED%84%B0%ED%94%84%EB%A0%88%EC%9E%84_%EB%8B%A4%EB%A3%A8%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Sprint2_Part2_Colab(2)_데이터프레임 다루기
#
# > 목표: 데이터프레임에 대한 기본적인 구조를 경험해보기
# > 내용: 데이터 확인 및 점검
#
# **데이터 정보 확인** shape, info(), describe()
# **결측치, 중복값 확인**  isnull, duplicated
# 기본 인덱싱, 슬라이싱, 불리언 인덱싱

# %% [markdown]
# ## 데이터 가져오기
# > 파일 경로를 입력하여 데이터를 손쉽게 가져올 수 있다.
# > 교안에서는 편의상 url로 대체하지만 colab에는 구글드라이브 마운트, 파일 업로드 등 다양한 방식이 있다.
#
#
# url로 데이터를 불러오고, 데이터 구조 및 정보, 수치정보를 확인해 본다.

# %% [markdown]
# ![titanic](https://velog.velcdn.com/images/chaliechu117/post/020dcc3d-7cd6-43c3-b696-116c6ac593bd/image.jpg)
#
# **해당 표는 편의를 위해 수기로 작성한 것이며, 일반적으로 칼럼 설명은 직접 찾아봐야 한다.**
#
#
# | 컬럼명             | 의미    | 설명                  |
# | --------------- | -------- | ------------------- |
# | **PassengerId** | 승객 ID    | 각 승객을 구분하기 위한 고유 번호 |
# | **Survived**    | 생존 여부    | 생존 = 1, 사망 = 0      |
# | **Pclass**      | 객실 등급    | 1등석 / 2등석 / 3등석     |
# | **Name**        | 이름       | 승객의 이름              |
# | **Sex**         | 성별       | male / female       |
# | **Age**         | 나이       | 승객의 나이      |
# | **SibSp**       | 형제·배우자 수 | 함께 탑승한 형제자매 + 배우자 수 |
# | **Parch**       | 부모·자녀 수  | 함께 탑승한 부모 + 자녀 수    |
# | **Ticket**      | 티켓 번호    | 승객의 티켓 고유 번호        |
# | **Fare**        | 요금       | 지불한 승선 요금           |
# | **Cabin**       | 객실 번호    | 객실 위치 정보   |
# | **Embarked**    | 탑승 항구    | 탑승한 항구 (C, Q, S)    |

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/rngus4656/datasets/refs/heads/main/S2/titanic.csv"

df = pd.read_csv(url)
df. head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# 데이터의 형태 확인 해당 데이터 테이블은 행 개수, 열 개수
df.shape
# Out:
# (891, 12)

# %%
# 데이터 info 확인
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# 데이터 수치 정보 확인
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# 보통 세개 찍고 들어간다. 쉐입, 인포, 디스크라이브.

# %% [markdown]
# ## pandas 기본 기능으로 df 살펴보기
# > 데이터 조회, 확인 및 선택 방법
#
# 기본 조회 메서드 head, tail, sample
# 데이터 프레임의 인덱싱: 라벨 인뎅싱 loc & 정수 인덱싱 iloc

# %%
# df의 가장 앞 부분 (디폴트 값 5)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# df의 가장 뒷 부분
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
# df의 무작위 샘플
df.sample(5, random_state=42)
# Out:
#      PassengerId  Survived  Pclass  \
# 709          710         1       3
# 439          440         0       2
# 840          841         0       3
# 720          721         1       2
# 39            40         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 709  Moubarek, Master. Halim Gonios ("William George")    male   NaN      1
# 439             Kvillner, Mr. Johan Henrik Johannesson    male  31.0      0
# 840                        Alhomaki, Mr. Ilmari Rudolf    male  20.0      0
# 720                  Harper, Miss. Annie Jessie "Nina"  female   6.0      0
# 39                         Nicola-Yarred, Miss. Jamila  female  14.0      1
#
#      Parch            Ticket     Fare Cabin Embarked
# 709      1              2661  15.2458   NaN        C
# 439      0        C.A. 18723  10.5000   NaN        S
# 840      0  SOTON/O2 3101287   7.9250   NaN        S
# 720      1            248727  33.0000   NaN        S
# ...

# %%
# 결측치
df.isnull()
df.isna()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
# 칼럼별 결측치(isna()=True)의 합
df.isnull().sum()
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# 특정 칼럼별 결측치 평균도 구할 수 있다.
df[['Age','Cabin']].isna().mean().round(2) # mean() 평균값, round(n) 소수 n번째까지 반올림
# Out:
# Age      0.20
# Cabin    0.77
# dtype: float64

# %%
# 중복값 점검
df.duplicated().sum()

# 고유값이 포함 된 중복값이 있을때는 df.drop_duplicates()로 제거 해 주는 것이 일반적이다.
# Out:
# np.int64(0)

# %% [markdown]
# ### 인덱싱과 슬라이싱, 데이터 선택
# 파이썬의 인덱스는 기본적으로 0부터 시작한다.
# 예를 들어, a = ['x', 'y', 'z']의 첫번째 인덱스인 x를 호출하기 위해 0번 인덱스를 조회한다.
# a[0] = 'x', a[1] = 'y', a[2] = 'z' (0번, 1번, 2번 Index 호출)
#
# * colab(1) 파이썬 기초 - '인덱스 구조' 참고

# %%
# 문자열, 리스트 등의 기본 인덱싱

a = ['x', 'y', 'z']
print(a[0])
print(a[1])
print(a[2])
# Out:
# x
# y
# z

# %%
# 슬라이싱의 기본 개념 a[시작:끝 -1] (디폴트값은 전체)

a = ['x', 'y', 'z']
print(a[0:2]) # 0번부터 1번까지 인덱싱
print(a[:3]) # 2번까지 인덱싱
print(a[1:]) #  1번부터 인덱싱
print(a[:]) # 전체 인덱싱
# Out:
# ['x', 'y']
# ['x', 'y', 'z']
# ['y', 'z']
# ['x', 'y', 'z']

# %%
# 기본 인덱싱 0부터 시작, 슬라이싱은 끝 -1 적용, 데이터 프레임의 기본 축은 axis = 행 0, 열 1

# 칼럼을 선택하는 가장 기본적인 방법
df['PassengerId'] # df.PassengerId 방식으로도 선택할 수 있지만, 코딩 편의상 [] 형식으로 통일.
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 886    887
# 887    888
# 888    889
# 889    890
# 890    891
# Name: PassengerId, Length: 891, dtype: int64

# %%
# 여러 칼럼을 선택할 수도 있다.
df[['PassengerId', 'Sex', 'Age', 'Ticket', 'Fare', 'Survived']]
# Out:
#      PassengerId     Sex   Age            Ticket     Fare  Survived
# 0              1    male  22.0         A/5 21171   7.2500         0
# 1              2  female  38.0          PC 17599  71.2833         1
# 2              3  female  26.0  STON/O2. 3101282   7.9250         1
# 3              4  female  35.0            113803  53.1000         1
# 4              5    male  35.0            373450   8.0500         0
# ..           ...     ...   ...               ...      ...       ...
# 886          887    male  27.0            211536  13.0000         0
# 887          888  female  19.0            112053  30.0000         1
# 888          889  female   NaN        W./C. 6607  23.4500         0
# 889          890    male  26.0            111369  30.0000         1
# 890          891    male  32.0            370376   7.7500         0
#
# [891 rows x 6 columns]

# %% [markdown]
# #### 라벨 인덱싱 loc, 정수 인덱싱 iloc
#
# 라벨 인덱싱: loc[행시작:행끝, 열시작:열끝]을 이용한 인덱싱 (시작: 끝) -> 문자열로 인식하여 인덱싱하는 방식
# 정수 인덱싱: iloc[행시작:행끝 -1, 열시작:열끝 -1]을 이용한 인덱싱 (시작:끝 -1) -> 가장 기본적으로 사용되는 방식

# %%
# 데이터 프레임 형식은 df['Survived':]을 입력하면 오류가 나온다.

# %%
# PassengerId를 인덱스로 가진 데이터 프레임의 인덱싱, 슬라이싱
df_a = df[['PassengerId', 'Sex', 'Age', 'Ticket', 'Fare', 'Survived']].set_index('PassengerId', drop=True)
df_a
# Out:
#                 Sex   Age            Ticket     Fare  Survived
# PassengerId
# 1              male  22.0         A/5 21171   7.2500         0
# 2            female  38.0          PC 17599  71.2833         1
# 3            female  26.0  STON/O2. 3101282   7.9250         1
# 4            female  35.0            113803  53.1000         1
# 5              male  35.0            373450   8.0500         0
# ...             ...   ...               ...      ...       ...
# 887            male  27.0            211536  13.0000         0
# 888          female  19.0            112053  30.0000         1
# 889          female   NaN        W./C. 6607  23.4500         0
# 890            male  26.0            111369  30.0000         1
# 891            male  32.0            370376   7.7500         0
#
# [891 rows x 5 columns]

# %%
# 라벨 인덱싱을 통한 행과 열 선택

df_a.loc[3:7, 'Ticket':'Survived'] # 해당 라벨을 탐색하여 호출함
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1739635524.py in <cell line: 0>()
#       1 # 라벨 인덱싱을 통한 행과 열 선택
#       2
# ----> 3 df_a.loc[3:7, 'Ticket':'Survived'] # 해당 라벨을 탐색하여 호출함
#
# NameError: name 'df_a' is not defined

# %%
# 정수 인덱싱을 통한 행과 열 선택

df_a.iloc[2:7, 2:5] # 해당 인덱스를 탐색하여 호출함

# %% [markdown]
# #### 불리언(boolean) 인덱싱
# 불리언 연산자에 따라 True, False 값으로 분류하여 조회하는 방식
# 데이터 프레임 형식으로는 df[df['칼럼'] 불리언 연산자]를 사용한다.
#
# 많이 쓰이는 불리언 연산자:
# <, >, ==, !=, |, &

# %%
# Survived가 1인 데이터 조회
df[df['Survived'] == 1].head() # df[df['Survived'] != 1].head()를 입력하면 반대의 결과가 출력 된다.(== <-> !=)
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
# Fare가 100이상인 데이터 조회  # .info() 넣어볼것 추가로
df[df['Fare'] >= 100].head()
# Out:
#      PassengerId  Survived  Pclass  \
# 27            28         0       1
# 31            32         1       1
# 88            89         1       1
# 118          119         0       1
# 195          196         1       1
#
#                                                Name     Sex   Age  SibSp  \
# 27                   Fortune, Mr. Charles Alexander    male  19.0      3
# 31   Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 88                       Fortune, Miss. Mabel Helen  female  23.0      3
# 118                        Baxter, Mr. Quigg Edmond    male  24.0      0
# 195                            Lurette, Miss. Elise  female  58.0      0
#
#      Parch    Ticket      Fare        Cabin Embarked
# 27       2     19950  263.0000  C23 C25 C27        S
# 31       0  PC 17569  146.5208          B78        C
# 88       2     19950  263.0000  C23 C25 C27        S
# 118      1  PC 17558  247.5208      B58 B60        C
# ...

# %%
# Fare가 100이상이거나, Survived가 1인 데이터 (OR 연산자)
df[(df['Fare'] >= 100) | (df['Survived'] == 1)].head()
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
# Fare가 100이상이면서, Survived도 1인 데이터 (AND 연산자)
df[(df['Fare'] >= 100) & (df['Survived'] == 1)].head()

# %% [markdown]
# # 데이터 조회 및 분석 준비
# 원하는 데이터를 조회하고, 용도에 맞게 재구성하며 분석을 준비한다.
# 데이터 조건부 조회: 불리언 인덱싱, contains(), (dtype + astype())
# 데이터 정렬 및 결측치 처리

# %% [markdown]
# ## 특정 값 조회
# 불리언 인덱싱, contains()를 통해 원하는 값만 조회

# %%
# df.str.contains()를 통해 원하는 문자열을 포함하는 데이터만 조회할 수 있다.

# 이름에 Mrs.가 붙은사람 조회
df[df['Name'].str.contains('Mrs.')].head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 8             9         1       3
# 9            10         1       2
# 15           16         1       2
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 3       0    113803  53.1000  C123        S
# 8       2    347742  11.1333   NaN        S
# 9       0    237736  30.0708   NaN        C
# 15      0    248706  16.0000   NaN        S

# %%
# 이름에 Mrs.가 붙고 Survived가 1인 사람 조회을 변수 df_Mrs에 저장
df_Mrs = df[(df['Name'].str.contains('Mrs')) & (df['Survived'] == 1)]
df_Mrs.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 8             9         1       3
# 9            10         1       2
# 15           16         1       2
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 3       0    113803  53.1000  C123        S
# 8       2    347742  11.1333   NaN        S
# 9       0    237736  30.0708   NaN        C
# 15      0    248706  16.0000   NaN        S

# %%
# df_Mrs의 value_counts 조회 -> 연속형 수치의 경우 유니크값이 너무 많아서 조회하기 힘들다.
df_Mrs.value_counts(subset='Age').head()
df_Mrs['Age'].value_counts().head()
# Out:
# Age
# 24.0    8
# 35.0    5
# 33.0    4
# 36.0    4
# 29.0    4
# Name: count, dtype: int64

# %%
# df_Mrs['Age']의 유니크값, 유니크값 개수 조회
print('Age칼럼의 유니크값:',df_Mrs['Age'].unique())
print('Age칼럼의 유니크값 개수:',df_Mrs['Age'].nunique()) # 개수에서 nan 결측치는 제외한다.
# Out:
# Age칼럼의 유니크값: [38. 35. 27. 14. 55. nan 49. 29. 33. 34. 24. 22. 40. 32. 44. 50. 58. 41.
#  19. 17. 36. 31. 60. 28. 42. 45. 23. 63. 54. 48. 39. 53. 52. 18. 30. 51.
#  43. 62. 15. 47. 56. 25.]
# Age칼럼의 유니크값 개수: 41

# %% [markdown]
# ## 결측치 중앙값으로 대체하기

# %%
# df['Age']의 중앙값 조회
df['Age'].median()
# Out:
# 28.0

# %%
# Age칼럼의 결측치 개수 확인
df[['Age']].isna().sum()
# Out:
# Age    177
# dtype: int64

# %%
# sort_values로 재확인
# 총 row 891에서 결측치 177을 제외하면 총 714개의 행이된다. 즉, 714개의 행에다한 중앙값을 계산하면 된다.
(df['Age'].dropna().sort_values(ascending=False).reset_index(drop=True)[356] + df['Age'].dropna().sort_values(ascending=False).reset_index(drop=True)[357]) / 2
# Out:
# np.float64(28.0)

# %%
# fillna로 결측치를 중앙값으로 대체
df_2 = df.copy()
df_2['Age'] = df_2['Age'].fillna(df_2['Age'].median())
print(df_2[['Age']].isna().sum())
df_2[['Age']].value_counts(ascending=False, dropna=False)
# Out:
# Age    0
# dtype: int64
# Age
# 28.0    202
# 24.0     30
# 22.0     27
# 18.0     26
# 19.0     25
#        ...
# 53.0      1
# 66.0      1
# 70.5      1
# 74.0      1
# 80.0      1
# Name: count, Length: 88, dtype: int64

# %% [markdown]
# 중앙값, 평균값, 최빈값 등 하나의 값으로 결측치를 처리한다면, 데이터 분포가 한쪽에 쏠릴 수 있기 때문에
# 데이터에 따라, 다양한 코드와 라이브러리를 활용한다.

# %%
# 심화 패턴: Age에 가장 영향을 많이 미친 Sex, Pclass 그룹당 median를 구하여 해당 값을 결측치로 대체

df.groupby(['Sex', 'Pclass'])['Age'].median()
# Out:
# Sex     Pclass
# female  1         35.0
#         2         28.0
#         3         21.5
# male    1         40.0
#         2         30.0
#         3         25.0
# Name: Age, dtype: float64

# %%
# 정답이라고 할 수 있는 방법은 없다. 다양한 기법과 라이브러리들이 있으니 데이터에따라 적절한 접근 방식을 설계 해보는 것이 필요하다.
df_3 = df.copy()
df_3['Age'] = df_3['Age'].fillna(df_3.groupby(['Sex', 'Pclass'])['Age'].transform('median'))
df_3['Age'].value_counts(ascending=False, dropna=False)
# Out:
# Age
# 25.00    117
# 21.50     42
# 30.00     34
# 40.00     34
# 24.00     30
#         ...
# 24.50      1
# 0.67       1
# 0.42       1
# 34.50      1
# 74.00      1
# Name: count, Length: 89, dtype: int64

# %%
df_3[['Age']].isna().sum()
# Out:
# Age    0
# dtype: int64

# %% [markdown]
# ## 새로운 Feature 생성
# 결측치가 있던 행들은 분석시 혼선을 줄 수 있으므로, 새로운 결측치 여부 Feature로 만들어 구분할 수 있다.
# 또한, 기존의 Feature를 기반으로 다양한 Feature Engineering을 수행 할 수 있다.

# %%
# 결측치가 가장 많은 객실정보 Cabin은 'unknown'으로 대체하고, Embarked는 결측치가 2개이므로 간단하게 최빈값으로 대체한다.

df_3['Cabin'] = df_3['Cabin'].fillna('unknown')
df_3['Embarked'] = df_3['Embarked'].fillna(df_3['Embarked'].mode()[0])

# %%
# Age_null 칼럼을 따로 만들어 두어, 결측치 여부를 판단할 수 있게 한다. (0, 1) 이진 분류

df_3['Age_null'] = df['Age'].isna().astype(int)
df_3
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### 새로운 라벨을 만들어 나이 카테고리 Feature 생성하기
# Age와 같은 중요하면서도 세그먼트가 나뉘는 데이터들은 분석에 따라 연속형 수치가 아닌 범주형으로 보는 것이 더 좋을 수 있다.

# %%
# 나이를 구간화, 카테고리화한 변수 지정하기

age_bins = [0, 12, 19, 34, 58, 100]
age_cat = ['Child', 'Teen', 'Young', 'Adult', 'Senior']

print(age_bins, age_cat)
# Out:
# [0, 12, 19, 34, 58, 100] ['Child', 'Teen', 'Young', 'Adult', 'Senior']

# %%
# pd.cut으로 라벨링 된 데이터 만들기

AgeGroup = pd.cut(df_3['Age'], bins=age_bins, labels=age_cat)
AgeGroup.head()
# Out:
# 0    Young
# 1    Adult
# 2    Young
# 3    Adult
# 4    Adult
# Name: Age, dtype: category
# Categories (5, object): ['Child' < 'Teen' < 'Young' < 'Adult' < 'Senior']

# %%
# 새로운 Feature인 AgeGroup 추가
df_3['AgeGroup'] = AgeGroup
df_3
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # 데이터 정제 및 분석 점검
# 몇 가지 핵심적인 정제를 마친 df_3로 어떤 분석을 할 수 있는지 연습 해보기

# %%
# 이름에 Mrs.를 포함하면서 생존한 사람 조회

df_3_Mrs = df_3[(df_3['Name'].str.contains('Mrs.') & df_3['Survived'] == 1)].reset_index(drop=True)
df_3_Mrs.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            2         1       1
# 1            4         1       1
# 2            9         1       3
# 3           10         1       2
# 4           16         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 2  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 3                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 4                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
#
#    Parch    Ticket     Fare    Cabin Embarked AgeGroup
# 0      0  PC 17599  71.2833      C85        C    Adult
# 1      0    113803  53.1000     C123        S    Adult
# 2      2    347742  11.1333  unknown        S    Young
# 3      0    237736  30.0708  unknown        C     Teen
# ...

# %%
# 생존한 기혼 여성은 대부분 Adult, Young 그룹에 속해있다.
df_3_Mrs[['AgeGroup']].value_counts()
# Out:
# AgeGroup
# Adult       50
# Young       40
# Teen         9
# Senior       3
# Child        0
# Name: count, dtype: int64

# %%
# 전체 연령 그룹을 확인했을때, 청년, 성인그룹이 가장 많이 분포되어 있다.
df_3['AgeGroup'].value_counts()
# Out:
# AgeGroup
# Young     461
# Adult     238
# Teen       95
# Child      69
# Senior     28
# Name: count, dtype: int64

# %%
# 객실 등급은 3등석이 가장 많았고, 2등석이 제일 적었다.
df_3['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
# 결측치가 많았던 Age, 영향 있었을까?
df_3.groupby("Age_null")["Survived"].mean()
# Out:
# Age_null
# 0    0.406162
# 1    0.293785
# Name: Survived, dtype: float64

# %%
# 생존한 객실 등급 그룹은 높을수록 생존율이 좋았다.
df_3.groupby("Pclass")["Survived"].mean().round(2)
# Out:
# Pclass
# 1    0.63
# 2    0.47
# 3    0.24
# Name: Survived, dtype: float64

# %%
# 생존한 성별 그룹을 볼 때, 성별은 여성 우선, 남성은 아이 우선으로 살리려고 한 것을 유추할 수 있다.
df_3.groupby(["Sex","AgeGroup"])["Survived"].mean().round(2)
# Out:
# /tmp/ipython-input-2062168476.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_3.groupby(["Sex","AgeGroup"])["Survived"].mean().round(2)
# Sex     AgeGroup
# female  Child       0.59
#         Teen        0.79
#         Young       0.71
#         Adult       0.81
#         Senior      1.00
# male    Child       0.57
#         Teen        0.10
#         Young       0.16
#         Adult       0.20
#         Senior      0.12
# Name: Survived, dtype: float64

# %%
# 객실 등급이 높을수록 전체적인 생존율이 높고, 나이가 적은 그룹이 우선적으로 생존된 걸 확인할 수 있다.
df_3.groupby(["Pclass", "AgeGroup"])["Survived"].mean().round(2)
# Out:
# /tmp/ipython-input-1027711335.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_3.groupby(["Pclass", "AgeGroup"])["Survived"].mean().round(2)
# Pclass  AgeGroup
# 1       Child       0.75
#         Teen        0.82
#         Young       0.73
#         Adult       0.60
#         Senior      0.29
# 2       Child       1.00
#         Teen        0.50
#         Young       0.43
#         Adult       0.40
#         Senior      0.20
# 3       Child       0.42
#         Teen        0.27
#         Young       0.24
#         Adult       0.09
#         Senior      0.17
# Name: Survived, dtype: float64

# %%
# 단순 비율뿐만 아니라, 승객 인원수에 따른 생존율과 평균적인 객실 요금 확인이 가능하다.
df_3.groupby(["Sex", "Pclass"]).agg(cnt_Id=("PassengerId", "count"),avg_survived=("Survived", "mean"),avg_fare=("Fare", "mean")).round(2)
# Out:
#                cnt_Id  avg_survived  avg_fare
# Sex    Pclass
# female 1           94          0.97    106.13
#        2           76          0.92     21.97
#        3          144          0.50     16.12
# male   1          122          0.37     67.23
#        2          108          0.16     19.74
#        3          347          0.14     12.66

# %% [markdown]
# # 연습 예제

# %% [markdown]
# 1. 어떤 AgeGroup이 가장 생존률이 높았고, 생존자 수가 가장 많은 그룹은 어디였을까?
#
# <details>
# <summary> Hint code </summary>
#
#
#
# ```
# print('[전체 인원]\n', df_3.groupby(['AgeGroup'])[['Survived']].count().sort_values(by='Survived', ascending=False),
#       '\n[생존자수]\n', df_3.groupby(['AgeGroup'])[['Survived']].sum().sort_values(by='Survived', ascending=False),
#       '\n[생존율]\n', df_3.groupby(['AgeGroup'])[['Survived']].mean().sort_values(by='Survived', ascending=False).round(2))
# ```
#
# ```
# df_3.groupby(['AgeGroup']).agg(cnt_group = ('AgeGroup', 'count'), cnt_survived = ('Survived', 'sum'), avg_survived =('Survived', 'mean')).round(2)
# ```
# </details>

# %%
df_3.groupby(['AgeGroup']).agg(cnt_group = ('AgeGroup', 'count'), cnt_survived = ('Survived', 'sum'), avg_survived =('Survived', 'mean')).round(2)
# Out:
# /tmp/ipython-input-2484806998.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_3.groupby(['AgeGroup']).agg(cnt_group = ('AgeGroup', 'count'), cnt_survived = ('Survived', 'sum'), avg_survived =('Survived', 'mean')).round(2)
#           cnt_group  cnt_survived  avg_survived
# AgeGroup
# Child            69            40          0.58
# Teen             95            39          0.41
# Young           461           155          0.34
# Adult           238           101          0.42
# Senior           28             7          0.25

# %% [markdown]
# 2. 성별과 객실 등급 중 어떤 특성이 생존에 미치는 영향이 강해보이는가?
#
# *성별과 객실 등급 각각 따로 확인, 정답은 없으니 자유롭게 분석 해보기*
#
# <details>
# <summary> Hint code </summary>
#
# ```
# df_3.groupby('Sex').agg(cnt=('Sex', 'count'), mean=('Survived', 'mean')).round(2)
# ```
#
# ```
# df_3.groupby('Pclass').agg(cnt=('Pclass', 'count'), mean=('Survived', 'mean')).round(2)
# ```
#
# </details>

# %%
# 성별 특성 분석
df_3.groupby('Sex').agg(cnt=('Sex', 'count'), mean=('Survived', 'mean')).round(2)
# Out:
#         cnt  mean
# Sex
# female  314  0.74
# male    577  0.19

# %%
# 객실 등급 특성 분석
df_3.groupby('Pclass').agg(cnt=('Pclass', 'count'), mean=('Survived', 'mean')).round(2)
# Out:
#         cnt  mean
# Pclass
# 1       216  0.63
# 2       184  0.47
# 3       491  0.24

# %% [markdown]
# **심화**
#  1. 데이터 Feature를 더 추가한다면, 어떤 특성을 추가할 수 있는가?

# %% [markdown]
# 2. 다른 데이터 셋으로도 비슷한 분석이 가능한가?
# <details>
# <summary>iris 데이터 셋</summary>
#
# ```
# import pandas as pd
# df = pd.read_csv("https://raw.githubusercontent.com/rngus4656/datasets/refs/heads/main/S2/iris.csv")
# df.head()
# ```
#
# </details>

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/rngus4656/datasets/refs/heads/main/S2/iris.csv")
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# # Task
# Calculate and visualize the survival rate for each passenger class (Pclass) from the `df_3` DataFrame, and then summarize how Pclass affects survival rates.

# %% [markdown]
# ## Analyze Pclass Survival
#
# ### Subtask:
# Calculate the count and mean survival rate for each passenger class (Pclass) from the dataframe `df_3`.

# %% [markdown]
# **Reasoning**:
# To calculate the count and mean survival rate for each passenger class, I will group the DataFrame by 'Pclass' and use the agg function to get the count of passengers and the mean of 'Survived', then round the results.

# %%
pclass_survival_analysis = df_3.groupby('Pclass').agg(count=('PassengerId', 'count'), mean_survived=('Survived', 'mean')).round(2)
pclass_survival_analysis
# Out:
#         count  mean_survived
# Pclass
# 1         216           0.63
# 2         184           0.47
# 3         491           0.24

# %% [markdown]
# ## Visualize Pclass Survival
#
# ### Subtask:
# Generate a bar plot to visualize the survival rate for each passenger class, clearly labeling the axes and providing a title. Make sure the y-axis (Survival Rate) ranges from 0 to 1.

# %% [markdown]
# **Reasoning**:
# To visualize the survival rate for each passenger class, I will generate a bar plot using Seaborn. This involves resetting the index of `pclass_survival_analysis` to convert 'Pclass' from an index to a column, and then using `sns.barplot` to create the plot with appropriate labels and a specified y-axis range.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Reset index to use 'Pclass' as a column for plotting
pclass_survival_analysis_plot = pclass_survival_analysis.reset_index()

plt.figure(figsize=(8, 5))
sns.barplot(x='Pclass', y='mean_survived', data=pclass_survival_analysis_plot, palette='viridis')
plt.title('Survival Rate by Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Survival Rate')
plt.ylim(0, 1)
plt.show()
# Out:
# /tmp/ipython-input-3521480188.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Pclass', y='mean_survived', data=pclass_survival_analysis_plot, palette='viridis')

# %% [markdown]
# **Reasoning**:
# The previous code produced a FutureWarning regarding the use of `palette` without `hue` in `sns.barplot`. To resolve this and ensure future compatibility, I will explicitly set `hue='Pclass'` and `legend=False` in the `sns.barplot` call, as suggested by the warning.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Reset index to use 'Pclass' as a column for plotting
pclass_survival_analysis_plot = pclass_survival_analysis.reset_index()

plt.figure(figsize=(8, 5))
sns.barplot(x='Pclass', y='mean_survived', data=pclass_survival_analysis_plot, palette='viridis', hue='Pclass', legend=False)
plt.title('Survival Rate by Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Survival Rate')
plt.ylim(0, 1)
plt.show()

# %% [markdown]
# ## Summary: How Pclass Affects Survival Rates
#
# Based on the analysis and visualization, there is a clear correlation between `Pclass` and survival rates:
#
# *   **First Class (Pclass 1):** Passengers in the first class had the highest survival rate at **0.63** (63%). This suggests that higher economic status and potentially better accommodations or priority in evacuation significantly increased their chances of survival.
# *   **Second Class (Pclass 2):** Second-class passengers had a moderate survival rate of **0.47** (47%). This is considerably lower than first class but higher than third class, indicating that their social standing and access to certain resources were better than those in third class, but not as privileged as first class.
# *   **Third Class (Pclass 3):** Passengers in the third class had the lowest survival rate, at just **0.24** (24%). This stark difference highlights that lower economic status, often associated with crowded conditions and less accessible deck locations, had a severely negative impact on survival chances.
#
# In conclusion, passenger class was a strong predictor of survival on the Titanic, with a clear hierarchy where higher classes experienced significantly better survival rates.

# %% [markdown]
# ## Summary: How Pclass Affects Survival Rates
#
# Based on the analysis and visualization, there is a clear correlation between `Pclass` and survival rates:
#
# *   **First Class (Pclass 1):** Passengers in the first class had the highest survival rate at **0.63** (63%). This suggests that higher economic status and potentially better accommodations or priority in evacuation significantly increased their chances of survival.
# *   **Second Class (Pclass 2):** Second-class passengers had a moderate survival rate of **0.47** (47%). This is considerably lower than first class but higher than third class, indicating that their social standing and access to certain resources were better than those in third class, but not as privileged as first class.
# *   **Third Class (Pclass 3):** Passengers in the third class had the lowest survival rate, at just **0.24** (24%). This stark difference highlights that lower economic status, often associated with crowded conditions and less accessible deck locations, had a severely negative impact on survival chances.
#
# In conclusion, passenger class was a strong predictor of survival on the Titanic, with a clear hierarchy where higher classes experienced significantly better survival rates.

# %% [markdown]
# ## Final Task
#
# ### Subtask:
# Summarize the findings about how passenger class (Pclass) affects survival rates.

# %% [markdown]
# ## Summary:
#
# ### Q&A
# Passenger class (Pclass) significantly affected survival rates, showing a clear inverse relationship: as the passenger class number increased (indicating a lower class), the survival rate decreased. Passengers in Pclass 1 had the highest survival rates, while those in Pclass 3 had the lowest.
#
# ### Data Analysis Key Findings
# *   Passengers in Pclass 1 had the highest survival rate, at 0.63 (63%).
# *   Passengers in Pclass 2 had a moderate survival rate, at 0.47 (47%).
# *   Passengers in Pclass 3 had the lowest survival rate, at 0.24 (24%).
# *   There is a strong correlation between passenger class and survival outcomes, indicating that higher classes experienced significantly better survival chances.
#
# ### Insights or Next Steps
# *   The stark differences in survival rates across Pclasses suggest that socioeconomic status, ship location, and potentially priority during evacuation were major determinants of survival on the Titanic.
# *   Further analysis could investigate other variables that might interact with Pclass, such as gender or age, to understand if these factors had different impacts on survival within each passenger class.
